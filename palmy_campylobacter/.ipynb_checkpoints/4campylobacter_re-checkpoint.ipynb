# %% [markdown]
# campylobacter pangenome for Patrick
# There were some Ns at the end of each genome, so I removed it
# this notebook use the four genomes as input for graph construction

# %%
#check the genome alignment by Mauve
from IPython import display
display.Image("./4campylobacter_mauve_align.jpg")

# %%
# !/opt/bioinf/samtools/1.9/bin/samtools faidx ./circ4_ST6964.fa

# %%
#Mash version 2.1 to calculate the distance for the genomes, which can be used as a guide for the similary -p for building the Pangenome graph
# !/opt/bioinf/mash/mash-2.1/bin/mash triangle ./circ4_ST6964.fa
# Out:
# 	4
# NZ_CP035895
# NZ_CP035894	0.0011856
# NZ_CP035892	0.00105797	0.000215742
# NZ_CP035891	0.000508006	0.000956583	0.000931334
# Max p-value: 0

# %%
# !/opt/bioinf/pggb/0.4.0/bin/pggb
# Out:
# ERROR: mandatory arguments -i and -n
# ERROR: -n must be greater than or equal to 2
# usage: /opt/conda/envs/pggb_0.4.0_singularity/bin/pggb -i <input-fasta> -n <n-mappings> [options]
# options:
#    [wfmash]
#     -i, --input-fasta FILE      input FASTA/FASTQ file
#     -s, --segment-length N      segment length for mapping [default: 5k]
#     -l, --block-length N        minimum block length filter for mapping [default: 5*segment-length]
#     -N, --no-split              disable splitting of input sequences during mapping [enabled by default]
#     -p, --map-pct-id PCT        percent identity for mapping/alignment [default: 90]
#     -n, --n-mappings N          number of mappings to retain for each segment
#     -x, --sparse-map N          keep this fraction of mappings ('auto' for giant component heuristic) [default: 1.0]
#     -K, --mash-kmer N           kmer size for mapping [default: 19]
#     -F, --mash-kmer-thres N     ignore the top % most-frequent kmers [default: 0.001]
#     -Y, --exclude-delim C       skip mappings between sequences with the same name prefix before
#                                 the given delimiter character [default: all-vs-all and !self]
#    [seqwish]
#     -k, --min-match-len N       filter exact matches below this length [default: 19]
#     -f, --sparse-factor N       keep this randomly selected fraction of input matches [default: no sparsification]
#     -B, --transclose-batch      number of bp to use for transitive closure batch [default: 10000000]
#    [smoothxg]
#     -H, --n-haps N              number of haplotypes, if different than that set with -n [default: n-mappings]
#     -j, --path-jump-max         maximum path jump to include in block [default: 0]
#     -e, --edge-jump-max N       maximum edge jump before breaking [default: 0 / off]
#     -G, --poa-length-target N,M target sequence length for POA, one per pass [default: 700,900,1100]
#     -P, --poa-params PARAMS     score parameters for POA in the form of match,mismatch,gap1,ext1,gap2,ext2
#                                 may also be given as presets: asm5, asm10, asm15, asm20
#                                 [default: 1,19,39,3,81,1 = asm5]
#     -O, --poa-padding N         pad each end of each sequence in POA with N*(mean_seq_len) bp [default: 0.001]
#     -b, --run-abpoa             run abPOA [default: SPOA]
#     -z, --global-poa            run the POA in global mode [default: local mode]
#     -d, --pad-max-depth N       depth/haplotype at which we don't pad the POA problem [default: 100]
#     -M, --write-maf             write MAF output representing merged POA blocks [default: off]
#     -Q, --consensus-prefix P    use this prefix for consensus path names [default: Consensus_]
#    [odgi]
#     -v, --skip-viz              don't render visualizations of the graph in 1D and 2D [default: make them]
#     -S, --stats                 generate statistics of the seqwish and smoothxg graph [default: off]
#    [vg]
#     -V, --vcf-spec SPEC         specify a set of VCFs to produce with SPEC = REF:DELIM[:LEN][,REF:DELIM:[LEN]]*
#                                 the paths matching ^REF are used as a reference, while the sample haplotypes
#                                 are derived from path names, e.g. when DELIM=# and with '-V chm13:#',
#                                 a path named HG002#1#ctg would be assigned to sample HG002 phase 1.
#                                 If LEN is specified and greater than 0, the VCFs are decomposed, filtering
#                                 sites whose max allele length is greater than LEN. [default: off]
#    [multiqc]
#     -m, --multiqc               generate MultiQC report of graphs' statistics and visualizations,
#                                 automatically runs odgi stats [default: off]
#    [general]
#     -o, --output-dir PATH       output directory
#     -D, --temp-dir PATH         directory for temporary files
#     -a, --input-paf FILE        input PAF file; the wfmash alignment step is skipped
#     -r, --resume                do not overwrite existing outputs in the given directory
#                                 [default: start pipeline from scratch]
#     -t, --threads N             number of compute threads to use in parallel steps
#     -T, --poa-threads N         number of compute threads to use during POA (set lower if you OOM during smoothing)
#     -A, --keep-temp-files       keep intermediate graphs
#     -Z, --compress              compress alignment (.paf), graph (.gfa, .og), and MSA (.maf) outputs with pigz,
#                                 and variant (.vcf) outputs with bgzip
#     -h, --help                  this text
#
# Use wfmash, seqwish, smoothxg, odgi, gfaffix, and vg to build, project and display a pangenome graph.

# %%
# !/opt/bioinf/pggb/0.4.0/bin/pggb -i ./circ4_ST6964.fa -s 1000 -p 95 -n 4 -t 48 -S -m -o circ4_ST6964_1k95
# Out:
# [wfmash::map] Reference = [./circ4_ST6964.fa]
# [wfmash::map] Query = [./circ4_ST6964.fa]
# [wfmash::map] Kmer size = 19
# [wfmash::map] Window size = 37
# [wfmash::map] Segment length = 1000 (read split allowed)
# [wfmash::map] Block length min = 5000
# [wfmash::map] Chaining gap max = 100000
# [wfmash::map] Percentage identity threshold = 95%
# [wfmash::map] Skip self mappings
# [wfmash::map] Mapping output file = circ4_ST6964_1k95/wfmash-b0nT3T
# [wfmash::map] Filter mode = 1 (1 = map, 2 = one-to-one, 3 = none)
# [wfmash::map] Execution threads  = 48
# [wfmash::skch::Sketch::build] minimizers picked from reference = 370180
# [wfmash::skch::Sketch::index] unique minimizers = 92601
# [wfmash::skch::Sketch::computeFreqHist] Frequency histogram of minimizers = (1, 312) ... (16, 54)
# [wfmash::skch::Sketch::computeFreqHist] With threshold 0.001%, consider all minimizers during lookup.
# [wfmash::map] time spent computing the reference index: 0.64325 sec
# [wfmash::skch::Map::mapQuery] mapped 100.00% @ 1.37e+06 bp/s elapsed: 00:00:00:05 remain: 00:00:00:00
# [wfmash::skch::Map::mapQuery] count of mapped reads = 3, reads qualified for mapping = 4, total input reads = 4, total input bp = 6880936
# [wfmash::map] time spent mapping the query: 5.02e+00 sec
# [wfmash::map] mapping results saved in: circ4_ST6964_1k95/wfmash-b0nT3T
# [wfmash::align] Reference = [./circ4_ST6964.fa]
# [wfmash::align] Query = [./circ4_ST6964.fa]
# [wfmash::align] Mapping file = circ4_ST6964_1k95/wfmash-b0nT3T
# [wfmash::align] Alignment identity cutoff = 7.60e-01%
# [wfmash::align] Alignment output file = /dev/stdout
# [wfmash::align] time spent loading the reference index: 3.67e-02 sec
# [wfmash::align::computeAlignments] aligned 100.00% @ 2.26e+06 bp/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [wfmash::align::computeAlignments] count of mapped reads = 4, total aligned bp = 10196267
# [wfmash::align] time spent computing the alignment: 4.55e+00 sec
# [wfmash::align] alignment results saved in: /dev/stdout
# wfmash -X -s 1000 -p 95 -n 3 -B circ4_ST6964_1k95 -t 48 ./circ4_ST6964.fa ./circ4_ST6964.fa
# 46.51s user 6.79s system 514% cpu 10.36s total 286504Kb max memory
# [seqwish::seqidx] 0.001 indexing sequences
# [seqwish::seqidx] 0.125 index built
# [seqwish::alignments] 0.125 processing alignments
# [seqwish::alignments] 0.177 indexing
# [seqwish::alignments] 0.182 index built
# [seqwish::transclosure] 0.197 computing transitive closures
# [seqwish::transclosure] 0.221 0.00% 0-6880936 overlap_collect
# [seqwish::transclosure] 0.707 0.00% 0-6880936 rank_build
# [seqwish::transclosure] 0.904 0.00% 0-6880936 parallel_union_find
# [seqwish::transclosure] 1.435 0.00% 0-6880936 dset_write
# [seqwish::transclosure] 1.545 0.00% 0-6880936 dset_compression
# [seqwish::transclosure] 1.611 0.00% 0-6880936 dset_sort
# [seqwish::transclosure] 1.672 0.00% 0-6880936 dset_invert
# [seqwish::transclosure] 1.736 0.00% 0-6880936 graph_emission
# [seqwish::transclosure] 2.748 100.00% building node_iitree and path_iitree indexes
# [seqwish::transclosure] 2.756 100.00% done
# [seqwish::transclosure] 2.756 done with transitive closures
# [seqwish::compact] 2.756 compacting nodes
# [seqwish::compact] 2.768 done compacting
# [seqwish::compact] 2.769 built node index
# [seqwish::links] 2.769 finding graph links
# [seqwish::links] 2.780 links derived
# [seqwish::gfa] 2.781 writing graph
# [seqwish::gfa] 3.051 done
# seqwish -t 48 -s ./circ4_ST6964.fa -p circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.wfmash.paf -k 19 -f 0 -g circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.seqwish.gfa -B 10000000 --temp-dir circ4_ST6964_1k95 -P
# 8.77s user 2.92s system 378% cpu 3.09s total 360844Kb max memory
# [smoothxg::main] loading graph
# [smoothxg::main] prepping graph for smoothing
# [odgi::gfa_to_handle] building nodes: 100.00% @ 2.05e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building edges: 100.00% @ 2.74e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building paths: 100.00% @ 1.54e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::prep] building path index
# [smoothxg::prep] sorting graph
# [odgi::path_linear_sgd] calculating linear SGD schedule (6.47e-06 1.00e+00 100 0 1.00e-02)
# [odgi::path_linear_sgd] calculating zetas for 393 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 5.26e+05/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] grooming: 100.00% @ 2.06e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] organizing handles: 100.00% @ 1.66e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] flipped 0 handles
# [odgi::topological_order] sorting nodes: 100.00% @ 2.06e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::prep] chopping graph to 100
# [odgi::chop] 156 node(s) to chop.
# [smoothxg::prep] writing graph circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.seqwish.gfa.prep.gfa
# [smoothxg::main] building xg index
# [smoothxg::smoothable_blocks] computing blocks
# [smoothxg::smoothable_blocks] computing blocks for 18543 handles: 100.00% @ 2.46e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::break_and_split_blocks] cutting blocks that contain sequences longer than max-poa-length (1400) and depth >= 0
# [smoothxg::break_and_split_blocks] splitting 2602 blocks at identity 0.950 (WFA-based clustering) and at estimated-identity 0.950 (mash-based clustering)
# [smoothxg::break_and_split_blocks] cutting and splitting 2602 blocks: 100.00% @ 9.95e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::break_and_split_blocks] cut 0 blocks of which 0 had repeats
# [smoothxg::break_and_split_blocks] split 0 blocks
# [smoothxg::smooth_and_lace] applying local SPOA to 2602 blocks: 100.00% @ 1.97e+02/s elapsed: 00:00:00:13 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] flipping 0 block graphs: 100.00% @ 3.92e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] sorting path_mappings
# [smoothxg::smooth_and_lace] adding edges from 2602 graphs: 100.00% @ 1.04e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] embedding 9879 path fragments: 100.00% @ 3.94e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] validating 4 path sequences: 100.00% @ 1.11e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] adding nodes from 2602 graphs: 100.00% @ 2.99e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] walking edges in 4 paths: 100.00% @ 1.59e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::main] unchopping smoothed graph
# [odgi::unchop] unchopped 2710 nodes into 129 new nodes.
# [smoothxg::main] smoothed graph length 1813480bp in 988 nodes
# [smoothxg::main] writing smoothed graph to circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.1.gfa
# smoothxg -t 48 -T 48 -g circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.seqwish.gfa -w 2800 -b circ4_ST6964_1k95 -X 100 -I .9500 -R 0 -j 0 -e 0 -l 700 -P 1,19,39,3,81,1 -O 0.001 -Y 400 -d 0 -D 0 -S -V -o circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.1.gfa
# 603.30s user 54.47s system 3350% cpu 19.63s total 925008Kb max memory
# [smoothxg::main] loading graph
# [smoothxg::main] prepping graph for smoothing
# [odgi::gfa_to_handle] building nodes: 100.00% @ 3.91e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building edges: 100.00% @ 5.43e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building paths: 100.00% @ 1.54e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::prep] building path index
# [smoothxg::prep] sorting graph
# [odgi::path_linear_sgd] calculating linear SGD schedule (1.97e-06 1.00e+00 100 0 1.00e-02)
# [odgi::path_linear_sgd] calculating zetas for 713 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 1.02e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] grooming: 100.00% @ 3.94e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] organizing handles: 100.00% @ 2.97e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] flipped 0 handles
# [odgi::topological_order] sorting nodes: 100.00% @ 3.94e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::prep] chopping graph to 100
# [odgi::chop] 151 node(s) to chop.
# [smoothxg::prep] writing graph circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.1.gfa.prep.gfa
# [smoothxg::main] building xg index
# [smoothxg::smoothable_blocks] computing blocks
# [smoothxg::smoothable_blocks] computing blocks for 19004 handles: 100.00% @ 2.52e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::break_and_split_blocks] cutting blocks that contain sequences longer than max-poa-length (1800) and depth >= 0
# [smoothxg::break_and_split_blocks] splitting 2024 blocks at identity 0.950 (WFA-based clustering) and at estimated-identity 0.950 (mash-based clustering)
# [smoothxg::break_and_split_blocks] cutting and splitting 2024 blocks: 100.00% @ 7.75e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::break_and_split_blocks] cut 0 blocks of which 0 had repeats
# [smoothxg::break_and_split_blocks] split 0 blocks
# [smoothxg::smooth_and_lace] applying local SPOA to 2024 blocks: 100.00% @ 1.49e+02/s elapsed: 00:00:00:13 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] flipping 0 block graphs: 100.00% @ 2.83e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] sorting path_mappings
# [smoothxg::smooth_and_lace] adding edges from 2024 graphs: 100.00% @ 8.08e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] embedding 7690 path fragments: 100.00% @ 3.06e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] validating 4 path sequences: 100.00% @ 1.11e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] adding nodes from 2024 graphs: 100.00% @ 2.33e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] walking edges in 4 paths: 100.00% @ 1.59e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::main] unchopping smoothed graph
# [odgi::unchop] unchopped 2123 nodes into 123 new nodes.
# [smoothxg::main] smoothed graph length 1813479bp in 985 nodes
# [smoothxg::main] writing smoothed graph to circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.2.gfa
# smoothxg -t 48 -T 48 -g circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.1.gfa -w 3600 -b circ4_ST6964_1k95 -X 100 -I .9500 -R 0 -j 0 -e 0 -l 900 -P 1,19,39,3,81,1 -O 0.001 -Y 400 -d 0 -D 0 -S -V -o circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.2.gfa
# 607.92s user 54.71s system 3335% cpu 19.86s total 1215608Kb max memory
# [smoothxg::main] loading graph
# [smoothxg::main] prepping graph for smoothing
# [odgi::gfa_to_handle] building nodes: 100.00% @ 3.91e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building edges: 100.00% @ 5.42e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building paths: 100.00% @ 1.54e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::prep] building path index
# [smoothxg::prep] sorting graph
# [odgi::path_linear_sgd] calculating linear SGD schedule (1.98e-06 1.00e+00 100 0 1.00e-02)
# [odgi::path_linear_sgd] calculating zetas for 711 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 1.02e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] grooming: 100.00% @ 3.93e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] organizing handles: 100.00% @ 2.97e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] flipped 0 handles
# [odgi::topological_order] sorting nodes: 100.00% @ 3.92e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::prep] chopping graph to 100
# [odgi::chop] 151 node(s) to chop.
# [smoothxg::prep] writing graph circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.2.gfa.prep.gfa
# [smoothxg::main] building xg index
# [smoothxg::smoothable_blocks] computing blocks
# [smoothxg::smoothable_blocks] computing blocks for 19001 handles: 100.00% @ 2.52e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::break_and_split_blocks] cutting blocks that contain sequences longer than max-poa-length (2200) and depth >= 0
# [smoothxg::break_and_split_blocks] splitting 1656 blocks at identity 0.950 (WFA-based clustering) and at estimated-identity 0.950 (mash-based clustering)
# [smoothxg::break_and_split_blocks] cutting and splitting 1656 blocks: 100.00% @ 6.34e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::break_and_split_blocks] cut 0 blocks of which 0 had repeats
# [smoothxg::break_and_split_blocks] split 0 blocks
# [smoothxg::smooth_and_lace] applying local SPOA to 1656 blocks: 100.00% @ 1.17e+02/s elapsed: 00:00:00:14 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] flipping 0 block graphs: 100.00% @ 2.60e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] sorting path_mappings
# [smoothxg::smooth_and_lace] adding edges from 1656 graphs: 100.00% @ 6.61e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] embedding 6291 path fragments: 100.00% @ 2.51e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] validating 4 path sequences: 100.00% @ 1.11e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] adding nodes from 1656 graphs: 100.00% @ 1.90e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] walking edges in 4 paths: 100.00% @ 1.59e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::main] unchopping smoothed graph
# [odgi::unchop] unchopped 1763 nodes into 123 new nodes.
# [smoothxg::main] smoothed graph length 1813479bp in 985 nodes
# [smoothxg::main] writing smoothed graph to circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.gfa
# smoothxg -t 48 -T 48 -g circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.2.gfa -w 4400 -b circ4_ST6964_1k95 -X 100 -I .9500 -R 0 -j 0 -e 0 -l 1100 -P 1,19,39,3,81,1 -O 0.001 -Y 400 -d 0 -D 0 -S -Q Consensus_ -V -o circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.gfa
# 630.01s user 56.93s system 3360% cpu 20.44s total 1519264Kb max memory
# gfaffix circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.gfa -o circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.fix.gfa
# 0.01s user 0.03s system 79% cpu 0.06s total 6588Kb max memory
# pigz
# 0.00s user 0.00s system 10% cpu 0.06s total 1052Kb max memory
# [odgi::gfa_to_handle] building nodes: 100.00% @ 3.91e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building edges: 100.00% @ 5.18e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building paths: 100.00% @ 1.54e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# odgi build -t 48 -P -g circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.fix.gfa -o - -O
# 0.08s user 0.11s system 23% cpu 0.85s total 8264Kb max memory
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (1.9726e-06 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 9.49e+05/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] grooming: 100.00% @ 3.92e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] organizing handles: 100.00% @ 3.03e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] flipped 0 handles
# [odgi::topological_order] sorting nodes: 100.00% @ 3.92e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# odgi sort -P -p Ygs --temp-dir circ4_ST6964_1k95 -t 48 -i - -o circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.final.og
# 14.14s user 0.13s system 748% cpu 1.90s total 21028Kb max memory
# odgi view -i circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.final.og -g
# 0.00s user 0.01s system 75% cpu 0.02s total 6692Kb max memory
# [odgi::gfa_to_handle] building nodes: 100.00% @ 2.05e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building edges: 100.00% @ 2.78e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building paths: 100.00% @ 1.55e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# odgi build -t 48 -P -g circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.seqwish.gfa -o circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.seqwish.og
# 0.07s user 0.06s system 16% cpu 0.81s total 8156Kb max memory
# odgi viz -i circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.final.og -o circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.final.og.viz_multiqc.png -x 1500 -y 500 -a 10 -I Consensus_
# 0.04s user 0.01s system 93% cpu 0.06s total 10364Kb max memory
# odgi viz -i circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.final.og -o circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.final.og.viz_pos_multiqc.png -x 1500 -y 500 -a 10 -u -d -I Consensus_
# 0.26s user 0.00s system 98% cpu 0.27s total 10788Kb max memory
# odgi viz -i circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.final.og -o circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.final.og.viz_depth_multiqc.png -x 1500 -y 500 -a 10 -m -I Consensus_
# 0.26s user 0.00s system 98% cpu 0.27s total 10556Kb max memory
# odgi viz -i circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.final.og -o circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.final.og.viz_inv_multiqc.png -x 1500 -y 500 -a 10 -z -I Consensus_
# 0.25s user 0.00s system 98% cpu 0.26s total 10508Kb max memory
# [odgi::path_linear_sgd_layout] 2D path-guided SGD: 100.00% @ 1.51e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# odgi layout -i circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.final.og -o circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.final.og.lay -T circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.final.og.lay.tsv -t 48 --temp-dir circ4_ST6964_1k95 -P
# 17.23s user 0.07s system 2139% cpu 0.80s total 20844Kb max memory
# odgi draw -i circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.final.og -c circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.final.og.lay -p circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.final.og.lay.draw.png -H 1000
# 10.17s user 0.88s system 139% cpu 7.90s total 788164Kb max memory
# odgi draw -i circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.final.og -c circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.final.og.lay -p circ4_ST6964_1k95/circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.final.og.lay.draw_multiqc.png -C -w 20 -H 1000
# 10.29s user 1.26s system 151% cpu 7.65s total 985384Kb max memory
#
#   /// MultiQC 🔍 | v1.13.dev0
#
# |           multiqc | Not cleaning sample names
# |           multiqc | Search path : /NGS/active/IPL/MENINGO/analysis/graph_genome/palmy_campylobacter/circ4_ST6964_1k95
# |         searching | ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 23/23
# |              odgi | Found 2 reports
# |           multiqc | Compressing plot data
# |           multiqc | Report      : circ4_ST6964_1k95/multiqc_report.html
# |           multiqc | Data        : circ4_ST6964_1k95/multiqc_data
# |           multiqc | MultiQC complete
# multiqc circ4_ST6964_1k95 -s -o circ4_ST6964_1k95 -c circ4_ST6964_1k95/multiqc_config.yaml
# 7.81s user 7.04s system 170% cpu 8.73s total 92824Kb max memory

# %%
# !/opt/bioinf/pggb/0.4.0/bin/pggb -i ./circ4_ST6964.fa -s 5000 -p 95 -n 4 -t 48 -S -m -o circ4_ST6964_5k95
# Out:
# [wfmash::map] Reference = [./circ4_ST6964.fa]
# [wfmash::map] Query = [./circ4_ST6964.fa]
# [wfmash::map] Kmer size = 19
# [wfmash::map] Window size = 188
# [wfmash::map] Segment length = 5000 (read split allowed)
# [wfmash::map] Block length min = 25000
# [wfmash::map] Chaining gap max = 100000
# [wfmash::map] Percentage identity threshold = 95%
# [wfmash::map] Skip self mappings
# [wfmash::map] Mapping output file = circ4_ST6964_5k95/wfmash-8IkD3I
# [wfmash::map] Filter mode = 1 (1 = map, 2 = one-to-one, 3 = none)
# [wfmash::map] Execution threads  = 48
# [wfmash::skch::Sketch::build] minimizers picked from reference = 72183
# [wfmash::skch::Sketch::index] unique minimizers = 18024
# [wfmash::skch::Sketch::computeFreqHist] Frequency histogram of minimizers = (1, 43) ... (16, 15)
# [wfmash::skch::Sketch::computeFreqHist] With threshold 0.001%, consider all minimizers during lookup.
# [wfmash::map] time spent computing the reference index: 0.398987 sec
# [wfmash::skch::Map::mapQuery] mapped 100.00% @ 4.58e+06 bp/s elapsed: 00:00:00:01 remain: 00:00:00:00
# [wfmash::skch::Map::mapQuery] count of mapped reads = 3, reads qualified for mapping = 4, total input reads = 4, total input bp = 6880936
# [wfmash::map] time spent mapping the query: 1.51e+00 sec
# [wfmash::map] mapping results saved in: circ4_ST6964_5k95/wfmash-8IkD3I
# [wfmash::align] Reference = [./circ4_ST6964.fa]
# [wfmash::align] Query = [./circ4_ST6964.fa]
# [wfmash::align] Mapping file = circ4_ST6964_5k95/wfmash-8IkD3I
# [wfmash::align] Alignment identity cutoff = 7.60e-01%
# [wfmash::align] Alignment output file = /dev/stdout
# [wfmash::align] time spent loading the reference index: 3.93e-02 sec
# [wfmash::align::computeAlignments] aligned 100.00% @ 2.26e+06 bp/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [wfmash::align::computeAlignments] count of mapped reads = 4, total aligned bp = 10196267
# [wfmash::align] time spent computing the alignment: 4.55e+00 sec
# [wfmash::align] alignment results saved in: /dev/stdout
# wfmash -X -s 5000 -p 95 -n 3 -B circ4_ST6964_5k95 -t 48 ./circ4_ST6964.fa ./circ4_ST6964.fa
# 31.04s user 4.57s system 540% cpu 6.58s total 284268Kb max memory
# [seqwish::seqidx] 0.001 indexing sequences
# [seqwish::seqidx] 0.129 index built
# [seqwish::alignments] 0.129 processing alignments
# [seqwish::alignments] 0.184 indexing
# [seqwish::alignments] 0.189 index built
# [seqwish::transclosure] 0.203 computing transitive closures
# [seqwish::transclosure] 0.228 0.00% 0-6880936 overlap_collect
# [seqwish::transclosure] 0.728 0.00% 0-6880936 rank_build
# [seqwish::transclosure] 0.916 0.00% 0-6880936 parallel_union_find
# [seqwish::transclosure] 1.443 0.00% 0-6880936 dset_write
# [seqwish::transclosure] 1.550 0.00% 0-6880936 dset_compression
# [seqwish::transclosure] 1.613 0.00% 0-6880936 dset_sort
# [seqwish::transclosure] 1.675 0.00% 0-6880936 dset_invert
# [seqwish::transclosure] 1.741 0.00% 0-6880936 graph_emission
# [seqwish::transclosure] 2.748 100.00% building node_iitree and path_iitree indexes
# [seqwish::transclosure] 2.756 100.00% done
# [seqwish::transclosure] 2.756 done with transitive closures
# [seqwish::compact] 2.756 compacting nodes
# [seqwish::compact] 2.769 done compacting
# [seqwish::compact] 2.770 built node index
# [seqwish::links] 2.770 finding graph links
# [seqwish::links] 2.781 links derived
# [seqwish::gfa] 2.781 writing graph
# [seqwish::gfa] 3.046 done
# seqwish -t 48 -s ./circ4_ST6964.fa -p circ4_ST6964_5k95/circ4_ST6964.fa.6099418.wfmash.paf -k 19 -f 0 -g circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.seqwish.gfa -B 10000000 --temp-dir circ4_ST6964_5k95 -P
# 7.91s user 3.79s system 379% cpu 3.08s total 361232Kb max memory
# [smoothxg::main] loading graph
# [smoothxg::main] prepping graph for smoothing
# [odgi::gfa_to_handle] building nodes: 100.00% @ 2.05e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building edges: 100.00% @ 2.72e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building paths: 100.00% @ 1.55e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::prep] building path index
# [smoothxg::prep] sorting graph
# [odgi::path_linear_sgd] calculating linear SGD schedule (6.47e-06 1.00e+00 100 0 1.00e-02)
# [odgi::path_linear_sgd] calculating zetas for 393 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 5.76e+05/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] grooming: 100.00% @ 5.23e+05/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] organizing handles: 100.00% @ 6.10e+05/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] flipped 0 handles
# [odgi::topological_order] sorting nodes: 100.00% @ 2.07e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::prep] chopping graph to 100
# [odgi::chop] 156 node(s) to chop.
# [smoothxg::prep] writing graph circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.seqwish.gfa.prep.gfa
# [smoothxg::main] building xg index
# [smoothxg::smoothable_blocks] computing blocks
# [smoothxg::smoothable_blocks] computing blocks for 18543 handles: 100.00% @ 2.46e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::break_and_split_blocks] cutting blocks that contain sequences longer than max-poa-length (1400) and depth >= 0
# [smoothxg::break_and_split_blocks] splitting 2602 blocks at identity 0.950 (WFA-based clustering) and at estimated-identity 0.950 (mash-based clustering)
# [smoothxg::break_and_split_blocks] cutting and splitting 2602 blocks: 100.00% @ 9.50e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::break_and_split_blocks] cut 0 blocks of which 0 had repeats
# [smoothxg::break_and_split_blocks] split 0 blocks
# [smoothxg::smooth_and_lace] applying local SPOA to 2602 blocks: 100.00% @ 1.97e+02/s elapsed: 00:00:00:13 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] flipping 0 block graphs: 100.00% @ 2.51e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] sorting path_mappings
# [smoothxg::smooth_and_lace] adding edges from 2602 graphs: 100.00% @ 1.04e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] embedding 9879 path fragments: 100.00% @ 3.94e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] validating 4 path sequences: 100.00% @ 1.12e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] adding nodes from 2602 graphs: 100.00% @ 3.00e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] walking edges in 4 paths: 100.00% @ 1.59e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::main] unchopping smoothed graph
# [odgi::unchop] unchopped 2710 nodes into 129 new nodes.
# [smoothxg::main] smoothed graph length 1813480bp in 988 nodes
# [smoothxg::main] writing smoothed graph to circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.1.gfa
# smoothxg -t 48 -T 48 -g circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.seqwish.gfa -w 2800 -b circ4_ST6964_5k95 -X 100 -I .9500 -R 0 -j 0 -e 0 -l 700 -P 1,19,39,3,81,1 -O 0.001 -Y 400 -d 0 -D 0 -S -V -o circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.1.gfa
# 598.00s user 54.08s system 3377% cpu 19.30s total 932500Kb max memory
# [smoothxg::main] loading graph
# [smoothxg::main] prepping graph for smoothing
# [odgi::gfa_to_handle] building nodes: 100.00% @ 3.92e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building edges: 100.00% @ 5.42e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building paths: 100.00% @ 1.54e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::prep] building path index
# [smoothxg::prep] sorting graph
# [odgi::path_linear_sgd] calculating linear SGD schedule (1.97e-06 1.00e+00 100 0 1.00e-02)
# [odgi::path_linear_sgd] calculating zetas for 713 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 1.02e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] grooming: 100.00% @ 3.95e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] organizing handles: 100.00% @ 2.45e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] flipped 0 handles
# [odgi::topological_order] sorting nodes: 100.00% @ 3.93e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::prep] chopping graph to 100
# [odgi::chop] 151 node(s) to chop.
# [smoothxg::prep] writing graph circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.1.gfa.prep.gfa
# [smoothxg::main] building xg index
# [smoothxg::smoothable_blocks] computing blocks
# [smoothxg::smoothable_blocks] computing blocks for 19004 handles: 100.00% @ 2.52e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::break_and_split_blocks] cutting blocks that contain sequences longer than max-poa-length (1800) and depth >= 0
# [smoothxg::break_and_split_blocks] splitting 2024 blocks at identity 0.950 (WFA-based clustering) and at estimated-identity 0.950 (mash-based clustering)
# [smoothxg::break_and_split_blocks] cutting and splitting 2024 blocks: 100.00% @ 7.65e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::break_and_split_blocks] cut 0 blocks of which 0 had repeats
# [smoothxg::break_and_split_blocks] split 0 blocks
# [smoothxg::smooth_and_lace] applying local SPOA to 2024 blocks: 100.00% @ 1.50e+02/s elapsed: 00:00:00:13 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] flipping 0 block graphs: 100.00% @ 2.48e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] sorting path_mappings
# [smoothxg::smooth_and_lace] adding edges from 2024 graphs: 100.00% @ 8.08e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] embedding 7690 path fragments: 100.00% @ 3.07e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] validating 4 path sequences: 100.00% @ 1.11e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] adding nodes from 2024 graphs: 100.00% @ 2.33e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] walking edges in 4 paths: 100.00% @ 1.59e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::main] unchopping smoothed graph
# [odgi::unchop] unchopped 2123 nodes into 123 new nodes.
# [smoothxg::main] smoothed graph length 1813479bp in 985 nodes
# [smoothxg::main] writing smoothed graph to circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.2.gfa
# smoothxg -t 48 -T 48 -g circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.1.gfa -w 3600 -b circ4_ST6964_5k95 -X 100 -I .9500 -R 0 -j 0 -e 0 -l 900 -P 1,19,39,3,81,1 -O 0.001 -Y 400 -d 0 -D 0 -S -V -o circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.2.gfa
# 607.01s user 54.08s system 3328% cpu 19.86s total 1210936Kb max memory
# [smoothxg::main] loading graph
# [smoothxg::main] prepping graph for smoothing
# [odgi::gfa_to_handle] building nodes: 100.00% @ 3.88e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building edges: 100.00% @ 5.41e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building paths: 100.00% @ 1.54e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::prep] building path index
# [smoothxg::prep] sorting graph
# [odgi::path_linear_sgd] calculating linear SGD schedule (1.98e-06 1.00e+00 100 0 1.00e-02)
# [odgi::path_linear_sgd] calculating zetas for 711 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 9.27e+05/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] grooming: 100.00% @ 3.92e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] organizing handles: 100.00% @ 3.19e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] flipped 0 handles
# [odgi::topological_order] sorting nodes: 100.00% @ 3.93e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::prep] chopping graph to 100
# [odgi::chop] 151 node(s) to chop.
# [smoothxg::prep] writing graph circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.2.gfa.prep.gfa
# [smoothxg::main] building xg index
# [smoothxg::smoothable_blocks] computing blocks
# [smoothxg::smoothable_blocks] computing blocks for 19001 handles: 100.00% @ 2.53e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::break_and_split_blocks] cutting blocks that contain sequences longer than max-poa-length (2200) and depth >= 0
# [smoothxg::break_and_split_blocks] splitting 1656 blocks at identity 0.950 (WFA-based clustering) and at estimated-identity 0.950 (mash-based clustering)
# [smoothxg::break_and_split_blocks] cutting and splitting 1656 blocks: 100.00% @ 6.26e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::break_and_split_blocks] cut 0 blocks of which 0 had repeats
# [smoothxg::break_and_split_blocks] split 0 blocks
# [smoothxg::smooth_and_lace] applying local SPOA to 1656 blocks: 100.00% @ 1.19e+02/s elapsed: 00:00:00:13 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] flipping 0 block graphs: 100.00% @ 3.20e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] sorting path_mappings
# [smoothxg::smooth_and_lace] adding edges from 1656 graphs: 100.00% @ 6.62e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] embedding 6291 path fragments: 100.00% @ 2.51e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] validating 4 path sequences: 100.00% @ 1.12e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] adding nodes from 1656 graphs: 100.00% @ 1.91e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] walking edges in 4 paths: 100.00% @ 1.59e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::main] unchopping smoothed graph
# [odgi::unchop] unchopped 1763 nodes into 123 new nodes.
# [smoothxg::main] smoothed graph length 1813479bp in 985 nodes
# [smoothxg::main] writing smoothed graph to circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.gfa
# smoothxg -t 48 -T 48 -g circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.2.gfa -w 4400 -b circ4_ST6964_5k95 -X 100 -I .9500 -R 0 -j 0 -e 0 -l 1100 -P 1,19,39,3,81,1 -O 0.001 -Y 400 -d 0 -D 0 -S -Q Consensus_ -V -o circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.gfa
# 630.77s user 55.86s system 3399% cpu 20.19s total 1505692Kb max memory
# gfaffix circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.gfa -o circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.fix.gfa
# 0.01s user 0.03s system 80% cpu 0.06s total 6584Kb max memory
# pigz
# 0.00s user 0.00s system 12% cpu 0.06s total 1052Kb max memory
# [odgi::gfa_to_handle] building nodes: 100.00% @ 3.92e+03/s elapsed: 00:00:00:00remain: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building edges: 100.00% @ 5.19e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building paths: 100.00% @ 1.54e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# odgi build -t 48 -P -g circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.fix.gfa -o - -O
# 0.08s user 0.10s system 21% cpu 0.85s total 8272Kb max memory
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (1.9726e-06 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 9.48e+05/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] grooming: 100.00% @ 3.92e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] organizing handles: 100.00% @ 2.60e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] flipped 0 handles
# [odgi::topological_order] sorting nodes: 100.00% @ 3.93e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# odgi sort -P -p Ygs --temp-dir circ4_ST6964_5k95 -t 48 -i - -o circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.final.og
# 13.87s user 0.22s system 736% cpu 1.91s total 19524Kb max memory
# odgi view -i circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.final.og -g
# 0.01s user 0.01s system 72% cpu 0.02s total 6712Kb max memory
# [odgi::gfa_to_handle] building nodes: 100.00% @ 2.06e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building edges: 100.00% @ 2.77e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building paths: 100.00% @ 1.54e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# odgi build -t 48 -P -g circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.seqwish.gfa -o circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.seqwish.og
# 0.08s user 0.07s system 19% cpu 0.81s total 8156Kb max memory
# odgi viz -i circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.final.og -o circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.final.og.viz_multiqc.png -x 1500 -y 500 -a 10 -I Consensus_
# 0.05s user 0.00s system 93% cpu 0.06s total 10364Kb max memory
# odgi viz -i circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.final.og -o circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.final.og.viz_pos_multiqc.png -x 1500 -y 500 -a 10 -u -d -I Consensus_
# 0.27s user 0.01s system 98% cpu 0.28s total 10756Kb max memory
# odgi viz -i circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.final.og -o circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.final.og.viz_depth_multiqc.png -x 1500 -y 500 -a 10 -m -I Consensus_
# 0.26s user 0.01s system 98% cpu 0.27s total 10572Kb max memory
# odgi viz -i circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.final.og -o circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.final.og.viz_inv_multiqc.png -x 1500 -y 500 -a 10 -z -I Consensus_
# 0.26s user 0.00s system 98% cpu 0.27s total 10512Kb max memory
# [odgi::path_linear_sgd_layout] 2D path-guided SGD: 100.00% @ 2.83e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# odgi layout -i circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.final.og -o circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.final.og.lay -T circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.final.og.lay.tsv -t 48 --temp-dir circ4_ST6964_5k95 -P
# 16.05s user 0.15s system 2930% cpu 0.55s total 20168Kb max memory
# odgi draw -i circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.final.og -c circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.final.og.lay -p circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.final.og.lay.draw.png -H 1000
# 9.88s user 0.93s system 136% cpu 7.93s total 788144Kb max memory
# odgi draw -i circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.final.og -c circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.final.og.lay -p circ4_ST6964_5k95/circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.final.og.lay.draw_multiqc.png -C -w 20 -H 1000
# 10.41s user 1.43s system 148% cpu 7.98s total 985356Kb max memory
#
#   /// MultiQC 🔍 | v1.13.dev0
#
# |           multiqc | Not cleaning sample names
# |           multiqc | Search path : /NGS/active/IPL/MENINGO/analysis/graph_genome/palmy_campylobacter/circ4_ST6964_5k95
# |         searching | ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 24/24
# |              odgi | Found 2 reports
# |           multiqc | Compressing plot data
# |           multiqc | Report      : circ4_ST6964_5k95/multiqc_report.html
# |           multiqc | Data        : circ4_ST6964_5k95/multiqc_data
# |           multiqc | MultiQC complete
# multiqc circ4_ST6964_5k95 -s -o circ4_ST6964_5k95 -c circ4_ST6964_5k95/multiqc_config.yaml
# 7.88s user 7.09s system 170% cpu 8.80s total 92836Kb max memory

# %%
# !/opt/bioinf/pggb/0.4.0/bin/pggb -i ./circ4_ST6964.fa -s 2000 -p 90 -n 4 -t 48 -S -m -o circ4_ST6964_2k90
# Out:
# [wfmash::map] Reference = [./circ4_ST6964.fa]
# [wfmash::map] Query = [./circ4_ST6964.fa]
# [wfmash::map] Kmer size = 19
# [wfmash::map] Window size = 54
# [wfmash::map] Segment length = 2000 (read split allowed)
# [wfmash::map] Block length min = 10000
# [wfmash::map] Chaining gap max = 100000
# [wfmash::map] Percentage identity threshold = 90%
# [wfmash::map] Skip self mappings
# [wfmash::map] Mapping output file = circ4_ST6964_2k90/wfmash-2vdQDH
# [wfmash::map] Filter mode = 1 (1 = map, 2 = one-to-one, 3 = none)
# [wfmash::map] Execution threads  = 48
# [wfmash::skch::Sketch::build] minimizers picked from reference = 252865
# [wfmash::skch::Sketch::index] unique minimizers = 63231
# [wfmash::skch::Sketch::computeFreqHist] Frequency histogram of minimizers = (1, 209) ... (16, 40)
# [wfmash::skch::Sketch::computeFreqHist] With threshold 0.001%, consider all minimizers during lookup.
# [wfmash::map] time spent computing the reference index: 0.547238 sec
# [wfmash::skch::Map::mapQuery] mapped 100.00% @ 1.72e+06 bp/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [wfmash::skch::Map::mapQuery] count of mapped reads = 3, reads qualified for mapping = 4, total input reads = 4, total input bp = 6880936
# [wfmash::map] time spent mapping the query: 4.01e+00 sec
# [wfmash::map] mapping results saved in: circ4_ST6964_2k90/wfmash-2vdQDH
# [wfmash::align] Reference = [./circ4_ST6964.fa]
# [wfmash::align] Query = [./circ4_ST6964.fa]
# [wfmash::align] Mapping file = circ4_ST6964_2k90/wfmash-2vdQDH
# [wfmash::align] Alignment identity cutoff = 7.20e-01%
# [wfmash::align] Alignment output file = /dev/stdout
# [wfmash::align] time spent loading the reference index: 3.29e-02 sec
# [wfmash::align::computeAlignments] aligned 100.00% @ 2.26e+06 bp/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [wfmash::align::computeAlignments] count of mapped reads = 4, total aligned bp = 10196267
# [wfmash::align] time spent computing the alignment: 4.54e+00 sec
# [wfmash::align] alignment results saved in: /dev/stdout
# wfmash -X -s 2000 -p 90 -n 3 -B circ4_ST6964_2k90 -t 48 ./circ4_ST6964.fa ./circ4_ST6964.fa
# 41.53s user 6.81s system 523% cpu 9.23s total 314896Kb max memory
# [seqwish::seqidx] 0.001 indexing sequences
# [seqwish::seqidx] 0.115 index built
# [seqwish::alignments] 0.115 processing alignments
# [seqwish::alignments] 0.168 indexing
# [seqwish::alignments] 0.172 index built
# [seqwish::transclosure] 0.188 computing transitive closures
# [seqwish::transclosure] 0.212 0.00% 0-6880936 overlap_collect
# [seqwish::transclosure] 0.738 0.00% 0-6880936 rank_build
# [seqwish::transclosure] 0.936 0.00% 0-6880936 parallel_union_find
# [seqwish::transclosure] 1.469 0.00% 0-6880936 dset_write
# [seqwish::transclosure] 1.573 0.00% 0-6880936 dset_compression
# [seqwish::transclosure] 1.636 0.00% 0-6880936 dset_sort
# [seqwish::transclosure] 1.699 0.00% 0-6880936 dset_invert
# [seqwish::transclosure] 1.764 0.00% 0-6880936 graph_emission
# [seqwish::transclosure] 2.864 100.00% building node_iitree and path_iitree indexes
# [seqwish::transclosure] 2.871 100.00% done
# [seqwish::transclosure] 2.871 done with transitive closures
# [seqwish::compact] 2.871 compacting nodes
# [seqwish::compact] 2.884 done compacting
# [seqwish::compact] 2.885 built node index
# [seqwish::links] 2.885 finding graph links
# [seqwish::links] 2.895 links derived
# [seqwish::gfa] 2.895 writing graph
# [seqwish::gfa] 3.158 done
# seqwish -t 48 -s ./circ4_ST6964.fa -p circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.wfmash.paf -k 19 -f 0 -g circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.seqwish.gfa -B 10000000 --temp-dir circ4_ST6964_2k90 -P
# 8.48s user 3.11s system 362% cpu 3.19s total 363356Kb max memory
# [smoothxg::main] loading graph
# [smoothxg::main] prepping graph for smoothing
# [odgi::gfa_to_handle] building nodes: 100.00% @ 2.07e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building edges: 100.00% @ 2.74e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building paths: 100.00% @ 1.56e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::prep] building path index
# [smoothxg::prep] sorting graph
# [odgi::path_linear_sgd] calculating linear SGD schedule (6.34e-06 1.00e+00 100 0 1.00e-02)
# [odgi::path_linear_sgd] calculating zetas for 397 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 5.82e+05/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] grooming: 100.00% @ 5.75e+05/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] organizing handles: 100.00% @ 1.94e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] flipped 0 handles
# [odgi::topological_order] sorting nodes: 100.00% @ 2.08e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::prep] chopping graph to 100
# [odgi::chop] 156 node(s) to chop.
# [smoothxg::prep] writing graph circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.seqwish.gfa.prep.gfa
# [smoothxg::main] building xg index
# [smoothxg::smoothable_blocks] computing blocks
# [smoothxg::smoothable_blocks] computing blocks for 18547 handles: 100.00% @ 2.47e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::break_and_split_blocks] cutting blocks that contain sequences longer than max-poa-length (1400) and depth >= 0
# [smoothxg::break_and_split_blocks] splitting 2603 blocks at identity 0.900 (WFA-based clustering) and at estimated-identity 0.900 (mash-based clustering)
# [smoothxg::break_and_split_blocks] cutting and splitting 2603 blocks: 100.00% @ 1.00e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::break_and_split_blocks] cut 0 blocks of which 0 had repeats
# [smoothxg::break_and_split_blocks] split 0 blocks
# [smoothxg::smooth_and_lace] applying local SPOA to 2603 blocks: 100.00% @ 1.83e+02/s elapsed: 00:00:00:14 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] flipping 0 block graphs: 100.00% @ 1.52e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] sorting path_mappings
# [smoothxg::smooth_and_lace] adding edges from 2603 graphs: 100.00% @ 1.04e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] embedding 9885 path fragments: 100.00% @ 3.95e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] validating 4 path sequences: 100.00% @ 1.12e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] adding nodes from 2603 graphs: 100.00% @ 3.00e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] walking edges in 4 paths: 100.00% @ 1.59e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::main] unchopping smoothed graph
# [odgi::unchop] unchopped 2711 nodes into 129 new nodes.
# [smoothxg::main] smoothed graph length 1813435bp in 991 nodes
# [smoothxg::main] writing smoothed graph to circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.1.gfa
# smoothxg -t 48 -T 48 -g circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.seqwish.gfa -w 2800 -b circ4_ST6964_2k90 -X 100 -I .9000 -R 0 -j 0 -e 0 -l 700 -P 1,19,39,3,81,1 -O 0.001 -Y 400 -d 0 -D 0 -S -V -o circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.1.gfa
# 613.87s user 54.57s system 3279% cpu 20.38s total 938780Kb max memory
# [smoothxg::main] loading graph
# [smoothxg::main] prepping graph for smoothing
# [odgi::gfa_to_handle] building nodes: 100.00% @ 3.93e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building edges: 100.00% @ 5.44e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building paths: 100.00% @ 1.54e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::prep] building path index
# [smoothxg::prep] sorting graph
# [odgi::path_linear_sgd] calculating linear SGD schedule (1.95e-06 1.00e+00 100 0 1.00e-02)
# [odgi::path_linear_sgd] calculating zetas for 717 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 9.14e+05/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] grooming: 100.00% @ 3.96e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] organizing handles: 100.00% @ 2.59e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] flipped 0 handles
# [odgi::topological_order] sorting nodes: 100.00% @ 3.96e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::prep] chopping graph to 100
# [odgi::chop] 151 node(s) to chop.
# [smoothxg::prep] writing graph circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.1.gfa.prep.gfa
# [smoothxg::main] building xg index
# [smoothxg::smoothable_blocks] computing blocks
# [smoothxg::smoothable_blocks] computing blocks for 19008 handles: 100.00% @ 2.53e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::break_and_split_blocks] cutting blocks that contain sequences longer than max-poa-length (1800) and depth >= 0
# [smoothxg::break_and_split_blocks] splitting 2026 blocks at identity 0.900 (WFA-based clustering) and at estimated-identity 0.900 (mash-based clustering)
# [smoothxg::break_and_split_blocks] cutting and splitting 2026 blocks: 100.00% @ 7.80e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::break_and_split_blocks] cut 0 blocks of which 0 had repeats
# [smoothxg::break_and_split_blocks] split 0 blocks
# [smoothxg::smooth_and_lace] applying local SPOA to 2026 blocks: 100.00% @ 1.42e+02/s elapsed: 00:00:00:14 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] flipping 0 block graphs: 100.00% @ 4.14e+05/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] sorting path_mappings
# [smoothxg::smooth_and_lace] adding edges from 2026 graphs: 100.00% @ 8.09e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] embedding 7697 path fragments: 100.00% @ 3.07e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] validating 4 path sequences: 100.00% @ 1.12e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] adding nodes from 2026 graphs: 100.00% @ 2.33e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] walking edges in 4 paths: 100.00% @ 1.59e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::main] unchopping smoothed graph
# [odgi::unchop] unchopped 2114 nodes into 123 new nodes.
# [smoothxg::main] smoothed graph length 1813433bp in 985 nodes
# [smoothxg::main] writing smoothed graph to circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.2.gfa
# smoothxg -t 48 -T 48 -g circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.1.gfa -w 3600 -b circ4_ST6964_2k90 -X 100 -I .9000 -R 0 -j 0 -e 0 -l 900 -P 1,19,39,3,81,1 -O 0.001 -Y 400 -d 0 -D 0 -S -V -o circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.2.gfa
# 624.75s user 56.00s system 3284% cpu 20.72s total 1195196Kb max memory
# [smoothxg::main] loading graph
# [smoothxg::main] prepping graph for smoothing
# [odgi::gfa_to_handle] building nodes: 100.00% @ 3.91e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building edges: 100.00% @ 5.41e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building paths: 100.00% @ 1.55e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::prep] building path index
# [smoothxg::prep] sorting graph
# [odgi::path_linear_sgd] calculating linear SGD schedule (1.97e-06 1.00e+00 100 0 1.00e-02)
# [odgi::path_linear_sgd] calculating zetas for 713 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 1.02e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] grooming: 100.00% @ 3.93e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] organizing handles: 100.00% @ 2.81e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] flipped 0 handles
# [odgi::topological_order] sorting nodes: 100.00% @ 3.93e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::prep] chopping graph to 100
# [odgi::chop] 151 node(s) to chop.
# [smoothxg::prep] writing graph circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.2.gfa.prep.gfa
# [smoothxg::main] building xg index
# [smoothxg::smoothable_blocks] computing blocks
# [smoothxg::smoothable_blocks] computing blocks for 19002 handles: 100.00% @ 2.53e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::break_and_split_blocks] cutting blocks that contain sequences longer than max-poa-length (2200) and depth >= 0
# [smoothxg::break_and_split_blocks] splitting 1659 blocks at identity 0.900 (WFA-based clustering) and at estimated-identity 0.900 (mash-based clustering)
# [smoothxg::break_and_split_blocks] cutting and splitting 1659 blocks: 100.00% @ 6.38e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::break_and_split_blocks] cut 0 blocks of which 0 had repeats
# [smoothxg::break_and_split_blocks] split 0 blocks
# [smoothxg::smooth_and_lace] applying local SPOA to 1659 blocks: 100.00% @ 1.13e+02/s elapsed: 00:00:00:14 remain: 00:00:00:00emain: 00:00:00:08
# [smoothxg::smooth_and_lace] flipping 0 block graphs: 100.00% @ 5.46e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] sorting path_mappings
# [smoothxg::smooth_and_lace] adding edges from 1659 graphs: 100.00% @ 6.62e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] embedding 6297 path fragments: 100.00% @ 2.51e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] validating 4 path sequences: 100.00% @ 1.12e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] adding nodes from 1659 graphs: 100.00% @ 1.91e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::smooth_and_lace] walking edges in 4 paths: 100.00% @ 1.59e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [smoothxg::main] unchopping smoothed graph
# [odgi::unchop] unchopped 1762 nodes into 123 new nodes.
# [smoothxg::main] smoothed graph length 1813433bp in 985 nodes
# [smoothxg::main] writing smoothed graph to circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.gfa
# smoothxg -t 48 -T 48 -g circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.2.gfa -w 4400 -b circ4_ST6964_2k90 -X 100 -I .9000 -R 0 -j 0 -e 0 -l 1100 -P 1,19,39,3,81,1 -O 0.001 -Y 400 -d 0 -D 0 -S -Q Consensus_ -V -o circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.gfa
# 644.31s user 57.68s system 3335% cpu 21.04s total 1518724Kb max memory
# gfaffix circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.gfa -o circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.fix.gfa
# 0.01s user 0.04s system 77% cpu 0.07s total 6616Kb max memory
# pigz
# 0.00s user 0.00s system 6% cpu 0.07s total 1052Kb max memory
# [odgi::gfa_to_handle] building nodes: 100.00% @ 3.94e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building edges: 100.00% @ 5.22e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building paths: 100.00% @ 1.54e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# odgi build -t 48 -P -g circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.fix.gfa -o - -O
# 0.09s user 0.07s system 18% cpu 0.85s total 8232Kb max memory
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (1.95609e-06 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 9.11e+05/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] grooming: 100.00% @ 3.46e+05/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] organizing handles: 100.00% @ 1.75e+05/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::groom] flipped 0 handles
# [odgi::topological_order] sorting nodes: 100.00% @ 3.87e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# odgi sort -P -p Ygs --temp-dir circ4_ST6964_2k90 -t 48 -i - -o circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.final.og
# 14.72s user 0.17s system 849% cpu 1.75s total 20944Kb max memory
# odgi view -i circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.final.og -g
# 0.00s user 0.01s system 78% cpu 0.02s total 6716Kb max memory
# [odgi::gfa_to_handle] building nodes: 100.00% @ 2.08e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building edges: 100.00% @ 2.78e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::gfa_to_handle] building paths: 100.00% @ 1.55e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# odgi build -t 48 -P -g circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.seqwish.gfa -o circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.seqwish.og
# 0.07s user 0.05s system 16% cpu 0.81s total 8164Kb max memory
# odgi viz -i circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.final.og -o circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.final.og.viz_multiqc.png -x 1500 -y 500 -a 10 -I Consensus_
# 0.04s user 0.01s system 93% cpu 0.06s total 10420Kb max memory
# odgi viz -i circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.final.og -o circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.final.og.viz_pos_multiqc.png -x 1500 -y 500 -a 10 -u -d -I Consensus_
# 0.31s user 0.01s system 99% cpu 0.33s total 10840Kb max memory
# odgi viz -i circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.final.og -o circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.final.og.viz_depth_multiqc.png -x 1500 -y 500 -a 10 -m -I Consensus_
# 0.27s user 0.00s system 98% cpu 0.28s total 10572Kb max memory
# odgi viz -i circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.final.og -o circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.final.og.viz_inv_multiqc.png -x 1500 -y 500 -a 10 -z -I Consensus_
# 0.26s user 0.01s system 98% cpu 0.27s total 10532Kb max memory
# [odgi::path_linear_sgd_layout] 2D path-guided SGD: 100.00% @ 2.78e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# odgi layout -i circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.final.og -o circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.final.og.lay -T circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.final.og.lay.tsv -t 48 --temp-dir circ4_ST6964_2k90 -P
# 13.60s user 0.13s system 2443% cpu 0.56s total 20844Kb max memory
# odgi draw -i circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.final.og -c circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.final.og.lay -p circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.final.og.lay.draw.png -H 1000
# 11.17s user 0.97s system 144% cpu 8.41s total 788172Kb max memory
# odgi draw -i circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.final.og -c circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.final.og.lay -p circ4_ST6964_2k90/circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.final.og.lay.draw_multiqc.png -C -w 20 -H 1000
# 10.36s user 1.23s system 148% cpu 7.82s total 985372Kb max memory
#
#   /// MultiQC 🔍 | v1.13.dev0
#
# |           multiqc | Not cleaning sample names
# |           multiqc | Search path : /NGS/active/IPL/MENINGO/analysis/graph_genome/palmy_campylobacter/circ4_ST6964_2k90
# |         searching | ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 23/23
# |              odgi | Found 2 reports
# |           multiqc | Compressing plot data
# |           multiqc | Report      : circ4_ST6964_2k90/multiqc_report.html
# |           multiqc | Data        : circ4_ST6964_2k90/multiqc_data
# |           multiqc | MultiQC complete
# multiqc circ4_ST6964_2k90 -s -o circ4_ST6964_2k90 -c circ4_ST6964_2k90/multiqc_config.yaml
# 7.82s user 7.18s system 171% cpu 8.73s total 92824Kb max memory

# %%
# !pwd
# Out:
# /NGS/active/IPL/MENINGO/analysis/graph_genome/palmy_campylobacter

# %%
# !mkdir pgge

# %%
# %cd ./circ4_ST6964_1k95/
# Out:
# /NGS/active/IPL/MENINGO/analysis/graph_genome/palmy_campylobacter/circ4_ST6964_1k95

# %%
# %cp circ4_ST6964.fa.ee113ce.417fcdf.9d98660.smooth.final.gfa circ4_ST6964.1k95.gfa

# %%
# %mv ./circ4_ST6964.1k95.gfa ./../pgge

# %%
# %cd ./../circ4_ST6964_5k95/
# Out:
# /NGS/active/IPL/MENINGO/analysis/graph_genome/palmy_campylobacter/circ4_ST6964_5k95

# %%
# %cp circ4_ST6964.fa.6099418.417fcdf.9d98660.smooth.final.gfa ./../pgge/circ4_ST6964.5k95.gfa

# %%
# %cd ./../circ4_ST6964_2k90/
# Out:
# /NGS/active/IPL/MENINGO/analysis/graph_genome/palmy_campylobacter/circ4_ST6964_2k90

# %%
# %cp ./circ4_ST6964.fa.af91cf8.417fcdf.53439a3.smooth.final.gfa ./../pgge/circ4_ST6964.2k90.gfa

# %%
# %cd ./../pgge
# Out:
# /NGS/active/IPL/MENINGO/analysis/graph_genome/palmy_campylobacter/pgge

# %%
# !/opt/bioinf/pgge/20210412/bin/pgge
# Out:
# Mandatory arguments -g, -f, -r. If running in GAF-MODE, only -i, -r are required.
# usage:    /usr/local/bin/pgge -g <input-gfa> -f <input-fasta> -r <beehave-r> [options]
#
# GAF-MODE: /usr/local/bin/pgge -i <input-gaf> [options]
#
# options:
#    [evaluation]
#     -g, --input-gfa FILE         input GFA file
#     -f, --input-fasta FILE       input FASTA file (uncompressed or gzipped)
#     -o, --output-dir FILE        output directory
#     -r, --beehave-r PATH         path to beehave.R
#     -b, --peanut-bed PATH        output BED file
#     -n, --input-graph-names TSV  input graph name file: first row is the name of the original input file, second row is the display name in the PNG
#     -v, --graphaligner-vg-mode   run GraphAligner with -x vg (default is -x dbg)
#    [splitfa]
#     -l, --seq-length N           length of the splits
#     -s, --step N                 step size between splits
#    [subsampling]
#     -p, --subsample-percentage N length of the splits
#     -u, --subsample-number N     step size between splits
#    [evaluation-gaf-mode]
#     -i, --input-gaf FILE         input GAF file
#    [general]
#     -t, --threads N              number of compute threads to use in parallel steps
#     -h, --help                   this text
#
# Uses GraphAligner and peanut to evaluate a pangenome graph. Utilizes samtools and splitfa.

# %%
# %cd ..
# Out:
# /NGS/active/IPL/MENINGO/analysis/graph_genome/palmy_campylobacter

# %%
# !cat pgge_circ4.sh
# Out:
# #!/bin/bash
#
# module load pgge/20210412
# inputGFA=./pgge/*.gfa
# input_folder=./pgge
# inputfa=./circ4_ST6964.fa
# output=./pgge
#
# for x in $inputGFA
# do
# pgge -g $x -f $inputfa -o $output -r /home/zyang/NGS/active/IPL/MENINGO/analysis/graph_genome/pgge/scripts/beehave.R -b $output/pgge_circ4_peanut_bed -l 100000 -s 5000 -t 16
#
# done

# %%
# %pwd
# Out:
# '/NGS/active/IPL/MENINGO/analysis/graph_genome/palmy_campylobacter'

# %%
# !mkdir vg_deconstruct

# %%
# !cp ./pgge/*.gfa ./vg_deconstruct/

# %%
# %cd ./vg_deconstruct/
# Out:
# /NGS/active/IPL/MENINGO/analysis/graph_genome/palmy_campylobacter/vg_deconstruct

# %%
# !pwd
# Out:
# /NGS/active/IPL/MENINGO/analysis/graph_genome/palmy_campylobacter/vg_deconstruct

# %%
# !/opt/bioinf/vg/1.41.0/bin/vg
# Out:
# vg: variation graph tool, version v1.41.0 "Salmour"
#
# usage: /opt/conda/envs/vg_1.41.0_singularity/bin/vg <command> [options]
#
# main mapping and calling pipeline:
#   -- autoindex     mapping tool-oriented index construction from interchange formats
#   -- construct     graph construction
#   -- rna           construct splicing graphs and pantranscriptomes
#   -- index         index graphs or alignments for random access or mapping
#   -- map           MEM-based read alignment
#   -- giraffe       fast haplotype-aware short read alignment
#   -- mpmap         splice-aware multipath alignment of short reads
#   -- augment       augment a graph from an alignment
#   -- pack          convert alignments to a compact coverage index
#   -- call          call or genotype VCF variants
#   -- help          show all subcommands
#
# For more commands, type `vg help`.
# For technical support, please visit: https://www.biostars.org/t/vg/

# %%
# !/opt/bioinf/vg/1.41.0/bin/vg deconstruct
# Out:
# usage: /opt/conda/envs/vg_1.41.0_singularity/bin/vg deconstruct [options] [-p|-P] <PATH> <GRAPH>
# Outputs VCF records for Snarls present in a graph (relative to a chosen reference path).
# options:
#     -p, --path NAME          A reference path to deconstruct against (multiple allowed).
#     -P, --path-prefix NAME   All paths (and/or GBWT threads) beginning with NAME used as reference (multiple allowed).
#                              Other non-ref paths not considered as samples.  When using a GBWT, select only samples with given prefix.
#     -H, --path-sep SEP       Obtain alt paths from the set of paths, assuming a path name hierarchy (e.g. SEP='#' and sample#phase#contig)
#     -r, --snarls FILE        Snarls file (from vg snarls) to avoid recomputing.
#     -g, --gbwt FILE          only consider alt traversals that correspond to GBWT threads FILE.
#     -T, --translation FILE   Node ID translation (as created by vg gbwt --translation) to apply to snarl names in output
#     -e, --path-traversals    Only consider traversals that correspond to paths in the graph.
#     -a, --all-snarls         Process all snarls, including nested snarls (by default only top-level snarls reported).
#     -d, --ploidy N           Expected ploidy.  If more traversals found, they will be flagged as conflicts (default: 2)
#     -c, --context-jaccard N  Set context mapping size used to disambiguate alleles at sites with multiple reference traversals (default: 10000).
#     -u, --untangle-travs     Use context mapping to determine the reference-relative positions of each step in allele traversals (AP INFO field).
#     -K, --keep-conflicted    Retain conflicted genotypes in output.
#     -S, --strict-conflicts   Drop genotypes when we have more than one haplotype for any given phase (set by default when using GBWT input).
#     -t, --threads N          Use N threads
#     -v, --verbose            Print some status messages

# %%
# !/opt/bioinf/vg/1.41.0/bin/vg deconstruct -p NZ_CP035891 -a -e -K  circ4_ST6964.1k95.gfa> circ4_ST6964_1k95_aeK_path1.vcf

# %%
# !/opt/bioinf/vg/1.41.0/bin/vg deconstruct -p NZ_CP035891 -a -e -K  circ4_ST6964.2k90.gfa> circ4_ST6964_2k90_aeK_path1.vcf

# %%
# !/opt/bioinf/vg/1.41.0/bin/vg deconstruct -p NZ_CP035891 -a -e -K  circ4_ST6964.5k95.gfa> circ4_ST6964_5k95_aeK_path1.vcf

# %%
# !pwd
# Out:
# /NGS/active/IPL/MENINGO/analysis/graph_genome/palmy_campylobacter/vg_deconstruct

# %%
# !cat compare_different_setting.sh
# Out:
# #!/bin/bash
#
# data=./*_aeK_path1.vcf
#
#
# for f in  $data
#
# do
# x=$(basename $f _aeK_path1.vcf)
# echo ${x}
#
# grep -v '#' ${x}_aeK_path1.vcf |cut -f 1-5 >${x}_aekp1vcf_sites
#
# done
#
# cat *_aekp1vcf_sites |sort -n -k 2,2 |uniq -c |sed s'/ /\t/g' |cut -f 7-12 >super_sites
#
#
#
# data2=./*_aekp1vcf_sites
#
# for b in $data2
#
# do
#
# y=$(basename $b _aekp1vcf_sites)
# echo ${y}
#
# perl cherk_variationSites_hash_graph.pl super_sites ${y}_aekp1vcf_sites |sed s'/ /\t/g' |cut -f 7  >super_sites_${y}
#
#
# done
# paste super_sites super_sites_circ4_ST6964_1k95 super_sites_circ4_ST6964_2k90 super_sites_circ4_ST6964_5k95   > super_sites_3settings
#
#
# awk '{for(i=7;i<=NF;i++){NUM=NUM?NUM+$i:$i};$(NF+1)=NUM;NUM=""} 1' super_sites_3settings |sed s'/ /\t/g' >super_sites_3settings_1

# %%
# !pwd
